# %% [markdown]
# # Phase 05: Conclusion and Reflection
#
# ## Part 02 - Self reflection
# - Student name: Pham Le Tu Nhi
# - Student ID: 21120308
#
# ### 1.1 Some takeaway for real estate for rent data analysis:
#
# Similar to Part 01 which analize real estate for sell, I can conclude that the distribution of real estates are uneven by districts in Ho Chi Minh city, which in term result in them having signature type of real estate.
#
# There has been a lot of interesting discoveries and real world connection that I was able to make from exploring this real estate dataset, which was interesting. The thing that surprised me the most was simply how expensive real estates are, and how cost differ from Districts, and from Property types. From a student standpoint, it gives me some context as for what to expect in the future interm of housing costs, which makes me realize what my prospects ought to be. I was wary of real estate cost at first (fears of being unable to afford my own place), but now, knowing (a little bit more) about the cost structure and real estate market (for rent) make me feel more confident and feel like be prepared to make a more informed decision when the time come.
#
# ### 1.2 Difficulties
#
# There is a lot of difficulties that I've encounter working on this project, some are directly related to our project but some barely. I want to cover this as much as I can because I think it's important to be honnest with your mistakes in order to improve.

# %% [markdown]
# #### 1.2.1 Technical and professional difficulties
#
# The hardest things for me doing this project was to understand the data set and consolidate what is it that I want to ask. In class we are taught how to *understand the data* and *ask meaningful question*, but being in a real situation with real artifacts to work with is very different. I forget about a lot of things, and I didn't have a clear cut ways to do things. In short, I was quite lost and didn't know what to do and how to do it **right**.
#
# <span style="color:grey">
# ---
# </span>
#
# To *understand the data*, I realized I had to know about some of it background and the context of data. I realize I have to ask questions about the data itself in hopes of ever be able to extracts anything useful from it.
# - Where does this data come from?
# - How is the data created?
# - Who is creating the data? and for whom?
#
# Answering these questions gives clarity to my understanding of the data. Still, it's the first step to asking question, not the last.
#
# <span style="color:grey">
# ---
# </span>
#
#
# To *ask meaningful question*, I have to know what I was interested in. That was a hard thing to do for me, because I tend to ask very broad questions and not quite knowing what I wanted to to **know**. After working on the project, there are some tips I've developed to help:
#
# > From what character's point of view am I viewing the data?
#
# Essentially what this is saying is I'm treating a dataset like a story, and I have to choose a character in that story's perspective to make sense of anything. There have to be a constant (perspective) to make sense of things because people understand things in the form of story. In my analysis, I take the perspective of the college student curious of the real estate market in Ho chi Minh. Yes, I did in a way - cosplay my self, but it bring context to my questions. Becuase asking a question from my point of view (a person who barely know anything about real estate) is different from the perspective of my parents (home owners) or of real estate agents (have access to large and accurate real estate data).
#
# In short, it helps me narrow down on what questions **I want to ask** and what answer **I can understand**.

# %% [markdown]
# > Chop the question into smaller pieces but make it clear what you want to answer
#
# In my analysis, you can see that I ask a big question and break it downs to smaller questions to understand it better. What you don't know is when I did that at first, I still didn't know what I wanted to ask. Only after I could provide an example of very specific questions under that question can I understand what answer. For example, take the first sub question of the first question that I post.
#
# <span style="color:grey">*How are the number of real estate for rent distributed across districts in Ho Chi Minh city?*</span>
#
# This is a very vague and over the place question. We don't know what is the subject and what is the action. To do that, I have to define the question further.
#
# <span style="color:grey">
# In other word, we are asking: </br>
# - Which districts has the most real estate property for rent? </br>
# - Which districts has the least real estate property for rent?
# </span>
#
# Defining the question further help us identify that the subject of the question is the **district**, and the action if to **rank/ classify** the district in a certain order.
#
# And finally concluding in a questions that actually lead us to the answer for the initial question that we post.
#
# <span style="color:grey">
# => <b>How big</b> is <b>the renting market</b> in <b>each districts</b> and how are they compared to each other.
# </span>
#
# This process help me understand the shape of the question and the data better, but I'm still not very good at it. Reading others analysis has been helful with this, and I believe this is a skills to build over time.
#
#
# <span style="color:grey">
# ---
# </span>
#
# With *programming*, most of the process has not been very difficult, though it is very time consuming. My fluency with python and Data Science flavour programming still aren't high, so I have to spend a lot of time look up code and methods in documentation and asking for help. Generative AI (ChatGPT) has been helpful in this regards, but I'm hoping to improve my code time and code quality with more practice.

# %% [markdown]
# #### 1.2.2 Productivity and personal difficulties
#
# This semester was an intense experience for me and for a lot of my friends as well. Almost if not all of the people I know in third year really struggled to keep up with studying and the amount of work they have to do. One of the thing that I had to undertake this year is staying up really late to complete my work - which personally was liberating timewise (I get to have more time) but it effects a lot of my health, and I believe it does with others.
#
# There are others things that comes up as well, and it has been difficult. Everything was messy. Watching the people around me succome to falling off their sleep schedule, not taking care of their health and burning out didn't help me realize what to do. What did was a personal crisis that sook my system to it cores, and it make me realize that I have to prioritize important things, over spending hours on ends on a problem I don't care about to get decent grades (I am not an honour student anyway). Time like this forces me to identify what was important and what I wanted to do. I HAD to choose, and in the end, I realized I can't have everything, and for the things I did choose, I have to respect it and show up, and actually try to work on them.
#
# And it always start now. The thing is, I can't wait till this (semester) is all over to start living. I have to do it know. And I started following that, which means I would to focus my energy to in more important things and literally just let go of others. It has been hard dealing with me not showing up to a lot of things I should be doing (being extreamly irresponsible in some regards), but I began to see things a bit more clearly. Some things matter more, and that's okay. Letting go of things was **very hard**, but it was my lesson that I'm trying to learn.
#
# <span style="color:grey">
# ---
# </span>
#
# ### 1.3 What I learned
#
# Most of the things I learned are all stemed from the difficuties that I faced, which I detailed above. But one important things I learned from this semester is the important of working with good teamates. Or rather, what it means to have a good teammate, which I was lucky to have a few.
#
# For me, having a good teammate is not having someone who would do all the work for you. It is very important for me that everyone in the team gets to participate and contribute to the project ends. A good teammate is someone who would be able to communicate well (telling me what I did wrong) and ask for help when needed.
#
# I was fortunate to have Huynh Cao Khoi as my teammate for this project. Though we are both unfamiliar with building a DS project, the team was copperative and very open to discussions from small ideas to major. I learned many things from working with Khoi, one of that is his orientation toward structured format and his cares towards designing a good visualization, and how he thinks about the people's experience reading and understanding his analysis. I think putting care into your craft and try to live up to your standard (even though you don't have the necessary experience and knowledge) is admirable.
#
#
# <span style="color:grey">
# ---
# </span>
#
# Another things that I learn is with our work process. We work in a parallel systems where I handle the rent data and Khoi handle the sell data. It's not a realistic approach because it takes a lot of time and I believe in a work setting people would settle for roles that is more specialize to their ability, but it is a good approach for educational purpose. Having essentially similar dataset makes us relate easily with one another findings while being different enough to **not get in each other ways**. We have had discussion about small details and big ideas in work and about real estate, and I think coming out we know more now than we got started, which is the ultimate goal for me.
#
# ### 1.4 What I will do next
#
# There are 4 things I would like to do after this project:
# - Analyze what is/what makes a good question a good question?
# - Learn more about statistics to understand probability and statistics better
# - Work on more project (perferably smaller size project)
# - Work on my planning scheduling skills
#
# These are the things I want to do after the project. I want to focus on a limited ammount of things first, stuff like understand questions/problems and improve understanding is important, so I will prioritize those.
#
# ### 1.5 Cross review
#
# This section is my review of my teammate, Khoi's work.
#
# #### 1.5.1 Interesting points
#
# Here are some points in Khoi's work that I found interesting:
# - His use of interactive graph: This is very good to help visualize and understand the data. Also, because he uses stacked bar chart, it helps a lot to not make the graph overwhelming and hard to see.
# - His use of `highlighted annotation` are clear and helpful for reading/skimming through the text.
# - His defined style of graph. It think it shows how meticulous he can be (which is a good thing most of the time).
#
# ##### Strength
#
# The strength of Khoi shows in his work in his ability to` manage and catagorize notebook`, and his meticulous attention to details of his analyis. The structure he choose are simple and logical, introduce the context, guiding the reader to get to know the data with graphs, give comments and summarise. Being consistent with practice takes attention and care, and I think it's shows in his work. His questions are also more discrete than mine, so I rely much on his suggestions moving along with my analysis.
#
# Working with Khoi, I also notice that he's a hard working person, and knows how to organize his work.
#
# ##### Weakness
#
# The weakness of Khoi shows not in his final products (I'm reading it again but all I realize is that I'm not very good at judging things) but in his work process. Khoi is hard working and a bit of a perfectionist, which prone him overwork himself and sometimes to burn out. I think feeling the need to tend to everything at once and make it good is important but knowing what is really that you're doing and what is the goal is very important too.
#
# Saying this, I don't think I'm any better. This is a lesson I'm still learning.
#
# Otherwise, many of his shortcomings are similar to mine. Our lack of domain knowledge, lack of application of statistics (comes in the form of using descriptive parameters, frequencies of using charts like boxplot), and taking a lot of times to work things out.
#
# ---
#
# That's then end of my analysis and work on this project. I'd like to express my gratitute for everyone who has helped me complete this project.
#
# Thank you HCK for being a good mate and carrying me :)
#
# Thank you Mr.Thanh for being pationate and teaching me a lot of stuff I didn't know before.
#
# Thank you Mr.Nam for answering my questions and giving me a better perspective on our industry.
#
# And thank you for reading.
