# %% [markdown]
# # <div style=" text-align: center; font-size: 50px; font-weight: bold">Phase 01: Collecting data </div>

# %% [markdown]
# ## **Import necessary Python modules**

# %%
import pandas as pd 
from bs4 import BeautifulSoup
from selenium import webdriver
import cloudscraper
import re

# %% [markdown]
# ## **Collect real estate for sale data:**
# In this section, we will collect the data of real estates that for sale from this website: https://batdongsan.com.vn/ . This webstite contain most of the advertisement of real estate (for rent or sale) in Viet Nam. In the scope of this project. We will focus on the data of real estate for sale, which are located in Ho Chi Minh City.
#
# Also, with the heavy density of the advertisement in this website. The data is collected is just mainly concentrate in just a period time (just in round end months of 2023). So for a overview, they cannot give us a full view about the current state of real estate in Ho Chi Minh City over times. Anyway, just don't get more concern to it and start our journey to collect data.

# %% [markdown]
# ### **1. Some initials:**

# %% [markdown]
# Look through the website, I can figure out some features that are common for most of real estate. So we can consider them like features that we should collect.
#
# Now, create an empty dataframe to store the data of the real estate. The dataframe will contain some features like: `Address`, `Type`, `Area`, `Price`, `Bedroom`, `Toilet`, `Floor`, `Furniture`, `Direction`, `Legal`, `Posting date`, `Expiry date`, `Ad type`, `Ad code`.

# %%
fields = [ 'Address', 'Type', 'Area', 'Price', 'Bedroom', 'Toilet', 'Floor', 'Furniture', 'Direction','Legal', 'Posting date', 'Expiry date', 'Ad type', 'Ad code']

# Create a empty data frame with these fields
df = pd.DataFrame(columns = fields)

# %% [markdown]
# ### **2. Collect the links to each real estate webpage:**
#
# The links are collected from multiple pages, with each page containing numerous links to apartments. These links have been stored in a file named `real_estate_for_sale_links.txt`.
#
# With this task , we can use `Selenium` to access the website and crawl data from it. The link to the homepage and the file name are provided below:

# %%
file_name = "../Data/real_estate_for_sale_links.txt"
url = 'https://batdongsan.com.vn/nha-dat-ban-tp-hcm'

# %% [markdown]
# We will move from the first page to the last page to collect the links, so the first thing should do is get the final page of the website.

# %%
def GetTotalPage(url):

    # Create an instance of the driver
    driver = webdriver.Chrome()
    driver.get(url)
    soup = BeautifulSoup(driver.page_source, 'html.parser')

    # The parsing data process
    unprocessed_num_page = soup.find(class_ = 're__pagination-group')
    driver.quit()

    regex = r'[^\s]+'
    matchs = re.findall(regex, unprocessed_num_page.text)
    new_array = []
    
    for match in matchs:
        new_array.append(int(match.replace('.', '')))

    total_page = max(new_array)

    return total_page

# %% [markdown]
# Process the result to get the last page.

# %%
total_page = GetTotalPage(url)

# %% [markdown]
# Function to collect the links to each real estate:

# %%
def CollectRealEstateForSaleLink (url, page):
    with open (file_name, 'w') as file:
        # Acess to all page
        for i in range(1, page + 1):
            driver = webdriver.Chrome()
            driver.get(url+'/p'+ str(i))
            soup = soup(driver.page_source, 'html.parser')
            apartment_list = soup.find_all("a", class_= "js__product-link-for-product-id")

            # Add all links to the file
            for apartment in apartment_list:
                link = 'https://batdongsan.com.vn/'+ apartment['href']
                file.write(link)
                file.write('\n')

            driver.quit()

# %%
CollectRealEstateForSaleLink (url, total_page)

# %% [markdown]
# Up to now, we have collected all the links to each real estate website and store them into a text file.

# %% [markdown]
# Read the `real_estate_for_sale_links.txt` file and store all the links to a lists

# %%
urls = []
with open(file_name, 'r') as file:
    for line in file.readlines():
            urls.append(line)

# %% [markdown]
# ### **3. Access to each link and colllect the data:**

# %% [markdown]
# The current language of the website is Vietnamese, and as just for some consitent, I try to convert them all to Englist by the dictionary below:

# %%
key_map = {
    'Địa chỉ:' : 'Address',
    'Diện tích': 'Area',
    'Mức giá': 'Price',
    'Hướng nhà': 'Direction',
    'Số tầng': 'Floor',
    'Số phòng ngủ': 'Bedroom',
    'Số toilet': 'Toilet',
    'Pháp lý': 'Legal',
    'Nội thất': 'Furniture',
    'Ngày đăng': 'Posting date',
    'Ngày hết hạn': 'Expiry date',
    'Loại tin': 'Ad type',
    'Mã tin': 'Ad code'
}

# %% [markdown]
# Also, look the through the website, I see that there are so many different types of real estates. This will be a important features for out future analysis. The issue here is the current data of each real estate that not contain its type, and the type is hide by the type code. Fortunaly, I have found all of them and store in the dictionary bellow:

# %%
sale_type = ['Căn hộ chung cư', 'Nhà riêng', 'Nhà biệt thự, liền kề', 'Nhà mặt phố', 'Shophouse nhà phố thương mại', 'Đất nền dự án', 'Đất bán', 'Trang trại, khu nghỉ dưỡng', 'Kho, nhà xưởng','Bất động sản khác']
sale_type_dict = {
    '324': sale_type[0], # Chung cư
    '41': sale_type[1], # Nhà riêng
    '325': sale_type[2], # biệt thự
    '163': sale_type[3], # Nhà mặt phố
    '575': sale_type[4], # Shophouse
    '40': sale_type[5], # Đất nền
    '283': sale_type[6], # Bán đất
    '44': sale_type[7], # Trang trại
    '45': sale_type[8], # kho
    '48': sale_type[9], # Khác
}

# %% [markdown]
# Now, let's define some necessary function of scrapping process:
#
# - Function to extract the features from a link:

# %%
def ExtractDataFromLinkWithSelenium(url):
    driver = webdriver.Chrome()
    try:
        driver.get(url)
        soup = BeautifulSoup(driver.page_source, 'html.parser')

        #Create a dicitonary to store the feature
        features = {}

        # get the address
        address = soup.find(class_ = "re__pr-short-description js__pr-address")

        # Get the type
        regex = r'[\d]+'
        type = soup.find_all('script', type= 'text/javascript')
        for item in type:
            if (item.text):
                found = re.findall(regex, item.text)
                break;
        # If the address cannot be found, mean the data is invalide, ignore them.
        if address == None:
            return features
        else:
            features['Address'] = address.text
            features['Type'] = sale_type_dict[found[3]]

        # Get all the features about the attribute of each real estate
        feature_items = soup.find_all('div', class_ = 're__pr-specs-content-item')
        for item in feature_items:
            title = item.find(class_ = 're__pr-specs-content-item-title').text.strip()
            value = item.find(class_ = 're__pr-specs-content-item-value').text.strip()
            features[title] = value

        # Get the features about the posting date, expiry date and the ad code
        date_items = soup.find_all( 'div', class_ = "re__pr-short-info-item js__pr-config-item")
        for item in date_items:
            title = item.find('span', class_ = 'title').text.strip()
            value = item.find('span',class_ = 'value').text.strip()
            features[title] = value
    
        # Convert all the keys to the defined keys base on the dictionary.
        keys_to_change = list(features.keys())
        for key in keys_to_change:
            if key in key_map:
                features[key_map[key]] = features[key]
    finally:
        driver.quit()

    return features

# %% [markdown]
# Iterate over the urls list and extract the data, which is stored in the previously defined DataFrame

# %%
for url in urls[ 1184 : 2000]:
        features = ExtractDataFromLinkWithSelenium(url)
        if features:
                new_row = pd.Series(features, index = fields)
                new_row_df = pd.DataFrame([new_row])
                df = pd.concat([df, new_row_df], ignore_index = True)
                # new_row_df.to_csv('../Data/real_estate_for_sale.csv', mode='a', header=False, index=False, encoding='utf-8')
        else:
                print ("Error")

# %% [markdown]
# ### **Note:**
# After many effort to collect the data, I find out that the executing time of Selenium is too long, this make the collecing data process become a challenge. So I came up with the solution that using another libraries to collect the data. And it was `CloudScraper`. In the next part, I will handle the collecting data process using `CloudScaper`
#
# ### **Collect data with CloudScraper:**

# %% [markdown]
# Now, reperform above process using `CloudScapper`

# %%
url = 'https://batdongsan.com.vn/nha-dat-ban-tp-hcm'
url_list = []

scraper = cloudscraper.create_scraper(delay=10, browser="chrome") 
content = scraper.get(url)

soup = BeautifulSoup(content.text, 'html.parser')
num_of_page = soup.find_all('a', class_='-numberre__pagination')

num_of_page = int(num_of_page[-1]['pid'])

# %%
# Get url list in first page
a_tags_list = soup.find_all('a', class_='js__product-link-for-product-id')
for a_tag in a_tags_list:
    url_list.append('https://batdongsan.com.vn/' + a_tag.get('href'))
url_list

# %%
page = '/p'
num_page = num_of_page
for num_page in range(2, int(num_page) + 1):
    content = scraper.get(url + page + str(num_page)).text
    soup = BeautifulSoup(content, 'html.parser')
    a_tags_list = soup.find_all('a', class_='js__product-link-for-product-id')
    for a_tag in a_tags_list:
        url_list.append('https://batdongsan.com.vn/' + a_tag.get('href'))

# %%
file_name = 'real_estate_for_sale_links.txt'

with open(file_name, 'w') as file:
    for line in url_list:
        file.write(line + "\n")

# %%
def ExtractDataFromLinkWithCloudscraper(url, scraper, headers):

    content = scraper.get(url, timeout=30, headers=headers)

    content.encoding = 'utf-8'
    soup = BeautifulSoup(content.text, 'html.parser')

    #Create a dicitonary to store the feature
    features = {}
    final_features = {}

    regex = r'[\d]+'
    type = soup.find('script', type='text/javascript')
    found = re.findall(regex, type.text)

    

    # get the address
    address = soup.find(class_ = "re__pr-short-description js__pr-address")

    if address is None:
        print(content)
        address = soup.find(class_ = 're__address-title js__product-address')
        if address is None:
            return final_features
        features['Địa chỉ:'] = address.text.strip()
        print("hihi")

        final_features['Type'] = sale_type_dict[found[3]]

        feature_items = soup.find_all('div', class_ = 're__pr-specs-content-item')
        for item in feature_items:
            title = item.find(class_ = 're__pr-specs-content-item-title').text.strip()
            value = item.find(class_ = 're__pr-specs-content-item-value').text.strip()
            features[title] = value

        date_items = soup.find_all( 'ul', class_ = "re__product-info")
        for item in date_items:
            title = item.find('span', class_ = 're__sp1').text.strip()
            value = item.find('span',class_ = 're__sp3').text.strip()
            features[title] = value

        keys_to_change = list(features.keys())

        for key in keys_to_change:
            if key in key_map:
                final_features[key_map[key]] = features[key]
        return final_features
    
    else:
        features['Địa chỉ:'] = address.text.strip()

        final_features['Type'] = sale_type_dict[found[3]]

        # Get all the features
        feature_items = soup.find_all('div', class_ = 're__pr-specs-content-item')
        for item in feature_items:
            title = item.find(class_ = 're__pr-specs-content-item-title').text.strip()
            value = item.find(class_ = 're__pr-specs-content-item-value').text.strip()
            features[title] = value

        date_items = soup.find_all( 'div', class_ = "re__pr-short-info-item js__pr-config-item")
        for item in date_items:
            title = item.find('span', class_ = 'title').text.strip()
            value = item.find('span',class_ = 'value').text.strip()
            features[title] = value

        keys_to_change = list(features.keys())

        for key in keys_to_change:
            if key in key_map:
                final_features[key_map[key]] = features[key]
        return final_features

# %%
urls = []
with open('../Data/real_estate_for_sale_links.txt', 'r') as file:
    for line in file.readlines():
            urls.append(line)

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}
scraper = cloudscraper.create_scraper(delay=10, browser="chrome") 
for url1 in urls[54723:]:
        features = ExtractDataFromLinkWithCloudscraper(url1[0:-1], scraper, headers)
        print(features)
        if features:
                new_row = pd.Series(features, index = fields)
                new_row_df = pd.DataFrame([new_row])
                df = pd.concat([df, new_row_df], ignore_index = True)
                # new_row_df.to_csv('../Data/real_estate_for_sale.csv', mode='a', header=False, index=False, encoding='utf-8')
        else:
                # break;
                
                print ("error")
# Out:
# {'Type': 'Nhà riêng', 'Address': 'Đường Nguyễn Sơn, Phường Phú Thạnh, Tân Phú, Hồ Chí Minh', 'Area': '68 m²', 'Price': '5 tỷ', 'Floor': '5 tầng', 'Bedroom': '11 phòng', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38573211'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Âu Cơ, Phường Tân Sơn Nhì, Tân Phú, Hồ Chí Minh', 'Area': '70 m²', 'Price': 'Thỏa thuận', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38572891'}
# {'Type': 'Nhà mặt phố', 'Address': 'Dự án Camellia Garden, Đường Nguyễn Văn Linh, Xã Bình Hưng, Bình Chánh, Hồ Chí Minh', 'Area': '74,1 m²', 'Price': '6,6 tỷ', 'Direction': 'Đông', 'Floor': '2 tầng', 'Bedroom': '3 phòng', 'Toilet': '2 phòng', 'Legal': 'Hợp đồng mua bán', 'Furniture': 'Đầy đủ', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38572046'}
# {'Type': 'Nhà riêng', 'Address': 'Phường Bình Trưng Đông, Quận 2, Hồ Chí Minh', 'Area': '82 m²', 'Price': '8 tỷ', 'Floor': '3 tầng', 'Bedroom': '4 phòng', 'Toilet': '4 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Đầy đủ', 'Posting date': '08/11/2023', 'Expiry date': '08/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38504344'}
# {'Type': 'Nhà riêng', 'Address': 'Phường Tăng Nhơn Phú B, Quận 9, Hồ Chí Minh', 'Area': '104 m²', 'Price': '7 tỷ', 'Floor': '2 tầng', 'Bedroom': '2 phòng', 'Toilet': '2 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Đầy đủ', 'Posting date': '09/11/2023', 'Expiry date': '09/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38509821'}
# {'Type': 'Nhà riêng', 'Address': 'Đường 8, Phường Tăng Nhơn Phú B, Quận 9, Hồ Chí Minh', 'Area': '66 m²', 'Price': '5,99 tỷ', 'Floor': '3 tầng', 'Bedroom': '4 phòng', 'Toilet': '4 phòng', 'Legal': 'Shr, hoàn công đầy đủ', 'Furniture': 'Đầy đủ cao câp', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38561794'}
# {'Type': 'Đất bán', 'Address': 'Phường Trường Thọ, Thủ Đức, Hồ Chí Minh', 'Area': '97 m²', 'Price': '7,6 tỷ', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Posting date': '10/11/2023', 'Expiry date': '10/12/2023', 'Ad type': 'Tin thường', 'Ad code': '37996881'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Võ Văn Ngân, Phường Bình Thọ, Thủ Đức, Hồ Chí Minh', 'Area': '65 m²', 'Price': '6,8 tỷ', 'Floor': '4 tầng', 'Bedroom': '4 phòng', 'Toilet': '5 phòng', 'Legal': 'Đã có sổ', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38572535'}
# {'Type': 'Căn hộ chung cư', 'Address': 'Dự án The Western Capital, Đường Lý Chiêu Hoàng, Phường 10, Quận 6, Hồ Chí Minh', 'Area': '54 m²', 'Price': 'Thỏa thuận', 'Direction': 'Đông', 'Bedroom': '2 phòng', 'Toilet': '1 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Đầy đủ', 'Posting date': '13/11/2023', 'Expiry date': '13/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38544361'}
# {'Type': 'Căn hộ chung cư', 'Address': 'Dự án Green Valley, Đường Tôn Dật Tiên, Phường Tân Phú, Quận 7, Hồ Chí Minh', 'Area': '224 m²', 'Price': '19,5 tỷ', 'Bedroom': '4 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Đầy đủ', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38571212'}
# {'Type': 'Căn hộ chung cư', 'Address': 'Dự án Masteri Centre Point, Đường Nguyễn Xiển, Phường Long Thạnh Mỹ, Quận 9, Hồ Chí Minh', 'Area': '75 m²', 'Price': '4,7 tỷ', 'Bedroom': '2 phòng', 'Toilet': '2 phòng', 'Legal': 'Hợp đồng mua bán', 'Furniture': 'Cơ bản', 'Posting date': '10/11/2023', 'Expiry date': '10/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38526123'}
# {'Type': 'Đất bán', 'Address': 'Xã Tân Hiệp, Hóc Môn, Hồ Chí Minh', 'Area': '7.000 m²', 'Price': '23 tỷ', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38572121'}
# {'Type': 'Đất bán', 'Address': 'Đường Tam Đa, Phường Trường Thạnh, Quận 9, Hồ Chí Minh', 'Area': '80 m²', 'Price': 'Thỏa thuận', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38572643'}
# {'Type': 'Căn hộ chung cư', 'Address': 'Dự án Moonlight Park View, Đường Số 7, Phường An Lạc A, Bình Tân, Hồ Chí Minh', 'Area': '71 m²', 'Price': '2,7 tỷ', 'Direction': 'Đông', 'Bedroom': '2 phòng', 'Toilet': '2 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Đầy đủ', 'Posting date': '13/11/2023', 'Expiry date': '13/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38544128'}
# {'Type': 'Căn hộ chung cư', 'Address': 'Dự án Opal Garden, Đường 20, Phường Hiệp Bình Chánh, Thủ Đức, Hồ Chí Minh', 'Area': '68 m²', 'Price': '3,45 tỷ', 'Bedroom': '2 phòng', 'Toilet': '2 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Cơ bản', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38572120'}
# {'Type': 'Nhà mặt phố', 'Address': 'Đường Trường Sa, Phường 1, Bình Thạnh, Hồ Chí Minh', 'Area': '505 m²', 'Price': '180 tỷ', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Đầy đủ', 'Posting date': '08/11/2023', 'Expiry date': '08/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38498847'}
# {'Type': 'Nhà riêng', 'Address': '1570, Đường Võ Văn Kiệt, Phường 7, Quận 6, Hồ Chí Minh', 'Area': '30,8 m²', 'Price': '6 tỷ', 'Floor': '3 tầng', 'Bedroom': '3 phòng', 'Toilet': '3 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38471150'}
# {'Type': 'Nhà biệt thự, liền kề', 'Address': 'Dự án Kim Sơn, Phường Tân Phong, Quận 7, Hồ Chí Minh', 'Area': '100 m²', 'Price': '16 tỷ', 'Direction': 'Đông', 'Floor': '4 tầng', 'Bedroom': '10 phòng', 'Toilet': '10 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Đầy đủ', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38280882'}
# {'Type': 'Căn hộ chung cư', 'Address': 'Dự án Moonlight Boulevard, Đường Kinh Dương Vương, Phường An Lạc A, Bình Tân, Hồ Chí Minh', 'Area': '68 m²', 'Price': '2,5 tỷ', 'Direction': 'Đông', 'Bedroom': '2 phòng', 'Toilet': '2 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Đầy đủ', 'Posting date': '13/11/2023', 'Expiry date': '13/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38543796'}
# {'Type': 'Đất bán', 'Address': 'Đường 28, Phường 6, Gò Vấp, Hồ Chí Minh', 'Area': '195,7 m²', 'Price': '16,5 tỷ', 'Direction': 'Đông - Bắc', 'Legal': 'Sổ đỏ/ Sổ hồng.', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '37430284'}
# {'Type': 'Nhà biệt thự, liền kề', 'Address': 'Dự án Kikyo Residence, Đường Đỗ Xuân Hợp, Phường Phước Long B, Quận 9, Hồ Chí Minh', 'Area': '198 m²', 'Price': '20,5 tỷ', 'Direction': 'Tây - Bắc', 'Floor': '2 tầng', 'Bedroom': '3 phòng', 'Toilet': '3 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38571503'}
# {'Type': 'Căn hộ chung cư', 'Address': 'Dự án One Verandah Mapletree, Đường Bát Nàn, Phường  Thạnh Mỹ Lợi, Quận 2, Hồ Chí Minh', 'Area': '55 m²', 'Price': '4,35 tỷ', 'Bedroom': '1 phòng', 'Toilet': '1 phòng', 'Legal': 'Hợp đồng mua bán', 'Furniture': 'Đầy đủ', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38570828'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Lê Văn Lương, Xã Phước Kiển, Nhà Bè, Hồ Chí Minh', 'Area': '75 m²', 'Price': '4,7 tỷ', 'Floor': '3 tầng', 'Bedroom': '4 phòng', 'Toilet': '5 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Đầy đủ', 'Posting date': '13/11/2023', 'Expiry date': '13/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38508224'}
# {'Type': 'Nhà riêng', 'Address': 'Hẻm 238, Đường Lê Văn Quới, Phường Bình Hưng Hòa A, Bình Tân, Hồ Chí Minh', 'Area': '68 m²', 'Price': '5,25 tỷ', 'Direction': 'Đông', 'Floor': '1 tầng', 'Bedroom': '2 phòng', 'Toilet': '1 phòng', 'Legal': 'Đã có sổ đỏ', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38336225'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Tây Thạnh, Phường Tây Thạnh, Tân Phú, Hồ Chí Minh', 'Area': '80 m²', 'Price': '6,6 tỷ', 'Floor': '1 tầng', 'Bedroom': '2 phòng', 'Toilet': '1 phòng', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38571386'}
# {'Type': 'Đất bán', 'Address': 'Đường Trần Quốc Toản, Phường Võ Thị Sáu, Quận 3, Hồ Chí Minh', 'Area': '605 m²', 'Price': '220 tỷ', 'Direction': 'Tây - Nam', 'Legal': 'Đã có sh', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38570467'}
# {'Type': 'Nhà riêng', 'Address': 'Phường 2, Phú Nhuận, Hồ Chí Minh', 'Area': '68 m²', 'Price': '16 tỷ', 'Floor': '6 tầng', 'Bedroom': '4 phòng', 'Toilet': '4 phòng', 'Legal': 'Đã có sổ', 'Furniture': 'Full nội thất', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38570662'}
# {'Type': 'Nhà riêng', 'Address': 'Đường 9, Phường Phước Bình, Quận 9, Hồ Chí Minh', 'Area': '86,22 m²', 'Price': '9,35 tỷ', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38571156'}
# {'Type': 'Căn hộ chung cư', 'Address': 'Dự án One Verandah Mapletree, Đường Bát Nàn, Phường  Thạnh Mỹ Lợi, Quận 2, Hồ Chí Minh', 'Area': '55 m²', 'Price': '4,35 tỷ', 'Bedroom': '1 phòng', 'Toilet': '1 phòng', 'Legal': 'Hợp đồng mua bán', 'Furniture': 'Đầy đủ', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38571232'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Lâm Văn Bền, Phường Tân Kiểng, Quận 7, Hồ Chí Minh', 'Area': '90 m²', 'Price': '7,65 tỷ', 'Floor': '2 tầng', 'Bedroom': '5 phòng', 'Toilet': '3 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Cơ bản', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38095011'}
# {'Type': 'Nhà mặt phố', 'Address': 'Đường Sư Vạn Hạnh, Phường 12, Quận 10, Hồ Chí Minh', 'Area': '104 m²', 'Price': '49 tỷ', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38570889'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Huỳnh Tấn Phát, Phường Tân Thuận Tây, Quận 7, Hồ Chí Minh', 'Area': '99 m²', 'Price': '9,9 tỷ', 'Floor': '3 tầng', 'Bedroom': '4 phòng', 'Toilet': '5 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Đầy đủ', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38172386'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Nguyễn Thị Thập, Phường Tân Phú, Quận 7, Hồ Chí Minh', 'Area': '69 m²', 'Price': '9,5 tỷ', 'Floor': '4 tầng', 'Bedroom': '5 phòng', 'Toilet': '6 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Cơ bản.', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38005058'}
# {'Type': 'Nhà riêng', 'Address': 'Đường  Trần Xuân Soạn, Phường Tân Hưng, Quận 7, Hồ Chí Minh', 'Area': '190 m²', 'Price': 'Thỏa thuận', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '37059335'}
# {'Type': 'Căn hộ chung cư', 'Address': 'Dự án The Morning Star Plaza, Đường Quốc Lộ 13, Phường 26, Bình Thạnh, Hồ Chí Minh', 'Area': '86 m²', 'Price': '3,2 tỷ', 'Bedroom': '2 phòng', 'Toilet': '2 phòng', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '24639495'}
# {'Type': 'Nhà biệt thự, liền kề', 'Address': 'Dự án Phú Xuân 4, Đường Huỳnh Tấn Phát, Xã Phú Xuân, Nhà Bè, Hồ Chí Minh', 'Area': '80 m²', 'Price': '6,5 tỷ', 'Direction': 'Đông - Nam', 'Floor': '4 tầng', 'Bedroom': '4 phòng', 'Toilet': '5 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Đầy đủ', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38005298'}
# {'Type': 'Căn hộ chung cư', 'Address': 'Dự án The Peak, Đường Nguyễn Lương Bằng, Phường Tân Phú, Quận 7, Hồ Chí Minh', 'Area': '130 m²', 'Price': 'Thỏa thuận', 'Furniture': 'Được bàn giao hoàn thiện nội thất cơ bản với vật liệu cao cấp nhập khẩu từ các thương hiệu lớn Châu Âu.', 'Posting date': '10/11/2023', 'Expiry date': '10/12/2023', 'Ad type': 'Tin thường', 'Ad code': '31263873'}
# {'Type': 'Nhà riêng', 'Address': 'Đường  Trần Xuân Soạn, Phường Tân Hưng, Quận 7, Hồ Chí Minh', 'Area': '58 m²', 'Price': '5,5 tỷ', 'Floor': '2 tầng', 'Bedroom': '2 phòng', 'Toilet': '1 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Đầy đủ', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '37016764'}
# {'Type': 'Shophouse nhà phố thương mại', 'Address': 'Dự án The Peak, Phường Tân Phú, Quận 7, Hồ Chí Minh', 'Area': '136 m²', 'Price': 'Thỏa thuận', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Posting date': '10/11/2023', 'Expiry date': '10/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38026349'}
# {'Type': 'Đất bán', 'Address': 'Đường Nguyễn Bình, Thị trấn Nhà Bè, Nhà Bè, Hồ Chí Minh', 'Area': '770 m²', 'Price': '36,5 tỷ', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '37009791'}
# {'Type': 'Đất bán', 'Address': 'Đường Huỳnh Tấn Phát, Phường Phú Thuận, Quận 7, Hồ Chí Minh', 'Area': '77 m²', 'Price': '6,2 tỷ', 'Legal': 'Đã có sổ', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '36281670'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Huỳnh Tấn Phát, Phường Phú Thuận, Quận 7, Hồ Chí Minh', 'Area': '150 m²', 'Price': '8,7 tỷ', 'Floor': '2 tầng', 'Bedroom': '3 phòng', 'Toilet': '3 phòng', 'Legal': 'Đã có sổ', 'Furniture': 'Cơ bản', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '36294911'}
# {'Type': 'Đất bán', 'Address': 'Đường Nguyễn Bình, Xã Nhơn Đức, Nhà Bè, Hồ Chí Minh', 'Area': '200 m²', 'Price': '5,5 tỷ', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '37024578'}
# {'Type': 'Nhà riêng', 'Address': 'Phường 13, Tân Bình, Hồ Chí Minh', 'Area': '90 m²', 'Price': '7,5 tỷ', 'Floor': '2 tầng', 'Bedroom': '4 phòng', 'Toilet': '2 phòng', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38569342'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Nguyễn Thị Tần, Phường 2, Quận 8, Hồ Chí Minh', 'Area': '75 m²', 'Price': '7,99 tỷ', 'Floor': '5 tầng', 'Bedroom': '7 phòng', 'Toilet': '7 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Đầy đủ', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38079854'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Lâm Văn Bền, Phường Tân Thuận Tây, Quận 7, Hồ Chí Minh', 'Area': '105 m²', 'Price': '8,79 tỷ', 'Floor': '2 tầng', 'Bedroom': '9 phòng', 'Toilet': '9 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Đầy đủ.', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38338331'}
# {'Type': 'Nhà riêng', 'Address': 'Phường Linh Đông, Thủ Đức, Hồ Chí Minh', 'Area': '90 m²', 'Price': 'Thỏa thuận', 'Floor': '2 tầng', 'Bedroom': '2 phòng', 'Toilet': '3 phòng', 'Legal': 'Sổ hồng chính chủ.', 'Posting date': '09/11/2023', 'Expiry date': '09/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38519463'}
# {'Type': 'Nhà riêng', 'Address': 'Phường Linh Tây, Thủ Đức, Hồ Chí Minh', 'Area': '79 m²', 'Price': 'Thỏa thuận', 'Floor': '3 tầng', 'Bedroom': '3 phòng', 'Legal': 'Sổ hồng.', 'Posting date': '09/11/2023', 'Expiry date': '09/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38519037'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Trung Lân 7, Xã Bà Điểm, Hóc Môn, Hồ Chí Minh', 'Area': '100 m²', 'Price': '5,9 tỷ', 'Direction': 'Bắc', 'Floor': '3 tầng', 'Bedroom': '4 phòng', 'Toilet': '4 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Cơ bản.', 'Posting date': '14/11/2023', 'Expiry date': '14/12/2023', 'Ad type': 'Tin thường', 'Ad code': '37221591'}
# {'Type': 'Căn hộ chung cư', 'Address': 'King Crown Infinity, 218, Đường Võ Văn Ngân, Phường Bình Thọ, Thủ Đức, Hồ Chí Minh', 'Area': '85 m²', 'Price': '8 tỷ', 'Direction': 'Nam', 'Bedroom': '2 phòng', 'Toilet': '2 phòng', 'Legal': 'Hợp đồng mua bán', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '34616479'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Tôn Đản, Phường 8, Quận 4, Hồ Chí Minh', 'Area': '82 m²', 'Price': '8,5 tỷ', 'Floor': '3 tầng', 'Bedroom': '3 phòng', 'Toilet': '4 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Đầy đủ', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38325706'}
# {'Type': 'Nhà riêng', 'Address': '1/, Đường Lê Đức Thọ, Phường 16, Gò Vấp, Hồ Chí Minh', 'Area': '48 m²', 'Price': '4,95 tỷ', 'Direction': 'Tây - Nam', 'Floor': '2 tầng', 'Bedroom': '2 phòng', 'Toilet': '3 phòng', 'Legal': 'Có xổ', 'Furniture': 'Cơ bản.', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38569873'}
# {'Type': 'Căn hộ chung cư', 'Address': 'Dự án Diamond Island, Phường Bình Trưng Tây, Quận 2, Hồ Chí Minh', 'Area': '90 m²', 'Price': '9 tỷ', 'Bedroom': '1 phòng', 'Toilet': '2 phòng', 'Furniture': 'Đầy đủ', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38569610'}
# {'Type': 'Nhà mặt phố', 'Address': '140, Đường Lý Tự Trọng, Phường Bến Nghé, Quận 1, Hồ Chí Minh', 'Area': '512 m²', 'Price': '1.100 tỷ', 'Floor': '12 tầng', 'Bedroom': '126 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Đầy đủ', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38370582'}
# {'Type': 'Nhà mặt phố', 'Address': '56, Đường Nguyễn Đình Chiểu, Phường Đa Kao, Quận 1, Hồ Chí Minh', 'Area': '508 m²', 'Price': '1.170 tỷ', 'Floor': '15 tầng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Đầy đủ', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38370667'}
# {'Type': 'Nhà mặt phố', 'Address': 'Đường Nguyễn Văn Đậu, Phường 11, Bình Thạnh, Hồ Chí Minh', 'Area': '104 m²', 'Price': '22 tỷ', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Cơ bản', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38273252'}
# {'Type': 'Nhà riêng', 'Address': '879/20/10/1A, Đường Hương lộ 2, Phường Bình Trị Đông A, Bình Tân, Hồ Chí Minh', 'Area': '80,7 m²', 'Price': '4,35 tỷ', 'Floor': '2 tầng', 'Bedroom': '2 phòng', 'Toilet': '2 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Không nội thất', 'Posting date': '14/11/2023', 'Expiry date': '14/12/2023', 'Ad type': 'Tin thường', 'Ad code': '36378220'}
# {'Type': 'Nhà mặt phố', 'Address': 'Đường Hoàng Hữu Nam, Phường Long Thạnh Mỹ, Quận 9, Hồ Chí Minh', 'Area': '300 m²', 'Price': '24 tỷ', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38478484'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Hồng Bàng, Phường 16, Quận 11, Hồ Chí Minh', 'Area': '120 m²', 'Price': '18,9 tỷ', 'Floor': '6 tầng', 'Legal': 'Sổ đỏ/ Sổ hồng.', 'Posting date': '09/12/2023', 'Expiry date': '08/01/2024', 'Ad type': 'Tin thường', 'Ad code': '36368870'}
# {'Type': 'Nhà riêng', 'Address': 'Đường 10, Phường Tân Quy, Quận 7, Hồ Chí Minh', 'Area': '40 m²', 'Price': '5,9 tỷ', 'Floor': '2 tầng', 'Legal': 'Sổ hồng chính chủ', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38569371'}
# {'Type': 'Đất bán', 'Address': 'Đường Hoàng Sa, Phường 9, Quận 3, Hồ Chí Minh', 'Area': '2.500 m²', 'Price': '650 tỷ', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38277135'}
# {'Type': 'Nhà mặt phố', 'Address': 'Xã Xuân Thới Sơn, Hóc Môn, Hồ Chí Minh', 'Area': '75,6 m²', 'Price': '4,5 tỷ', 'Direction': 'Tây', 'Floor': '2 tầng', 'Bedroom': '3 phòng', 'Toilet': '3 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Cơ bản', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38565509'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Lê Trọng Tấn, Phường Bình Hưng Hòa, Bình Tân, Hồ Chí Minh', 'Area': '36 m²', 'Price': '2,68 tỷ', 'Direction': 'Tây', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Cơ bản', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38567848'}
# {'Type': 'Đất nền dự án', 'Address': 'Dự án Kikyo Residence, Đường Đỗ Xuân Hợp, Phường Phước Long B, Quận 9, Hồ Chí Minh', 'Area': '162 m²', 'Price': '68 triệu/m²', 'Direction': 'Bắc', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38468966'}
# {'Type': 'Căn hộ chung cư', 'Address': 'Dự án Elysian, Đường Lò Lu, Phường Trường Thạnh, Quận 9, Hồ Chí Minh', 'Area': '80 m²', 'Price': '4,09 tỷ', 'Bedroom': '2 phòng', 'Toilet': '2 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Posting date': '10/11/2023', 'Expiry date': '10/12/2023', 'Ad type': 'Tin thường', 'Ad code': '37981203'}
# {'Type': 'Căn hộ chung cư', 'Address': 'Dự án Masteri Thảo Điền, Đường Xa Lộ Hà Nội, Phường Thảo Điền, Quận 2, Hồ Chí Minh', 'Area': '63 m²', 'Price': '4,8 tỷ', 'Direction': 'Đông - Nam', 'Bedroom': '2 phòng', 'Toilet': '2 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Đầy đủ', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38567810'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Trần Hưng Đạo, Phường 2, Quận 5, Hồ Chí Minh', 'Area': '50 m²', 'Price': 'Thỏa thuận', 'Floor': '1 tầng', 'Bedroom': '3 phòng', 'Toilet': '2 phòng', 'Legal': 'Đã có sổ', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38573443'}
# {'Type': 'Nhà mặt phố', 'Address': 'Đường Nguyễn Duy Trinh, Phường Long Trường, Quận 9, Hồ Chí Minh', 'Area': '350 m²', 'Price': '25 tỷ', 'Legal': 'Sổ hồng', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38568169'}
# {'Type': 'Đất nền dự án', 'Address': 'Dự án Dương Hồng Garden House, Đường Nguyễn Văn Linh, Xã Bình Hưng, Bình Chánh, Hồ Chí Minh', 'Area': '100 m²', 'Price': '8 tỷ', 'Legal': 'Hợp đồng mua bán.', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '34820944'}
# {'Type': 'Đất nền dự án', 'Address': 'Dự án Mizuki Park, Đường Nguyễn Văn Linh, Xã Bình Hưng, Bình Chánh, Hồ Chí Minh', 'Area': '100 m²', 'Price': '7,55 tỷ', 'Direction': 'Đông', 'Legal': 'Hợp đồng mua bán.', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '34734203'}
# {'Type': 'Nhà biệt thự, liền kề', 'Address': 'Dự án Mizuki Park, Đường Nguyễn Văn Linh, Xã Bình Hưng, Bình Chánh, Hồ Chí Minh', 'Area': '100 m²', 'Price': '12,4 tỷ', 'Direction': 'Đông', 'Floor': '3 tầng', 'Bedroom': '4 phòng', 'Toilet': '3 phòng', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '34763633'}
# {'Type': 'Nhà biệt thự, liền kề', 'Address': 'Dự án Mizuki Park, Đường Nguyễn Văn Linh, Xã Bình Hưng, Bình Chánh, Hồ Chí Minh', 'Area': '100 m²', 'Price': '7,6 tỷ', 'Floor': '3 tầng', 'Bedroom': '5 phòng', 'Toilet': '4 phòng', 'Legal': 'Hợp đồng mua bán.', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '34100757'}
# {'Type': 'Căn hộ chung cư', 'Address': 'Dự án The Western Capital, Đường Lý Chiêu Hoàng, Phường 10, Quận 6, Hồ Chí Minh', 'Area': '46 m²', 'Price': '1,9 tỷ', 'Bedroom': '2 phòng', 'Toilet': '1 phòng', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '37165977'}
# {'Type': 'Căn hộ chung cư', 'Address': 'Dự án The Western Capital, Đường Lý Chiêu Hoàng, Phường 10, Quận 6, Hồ Chí Minh', 'Area': '50 m²', 'Price': '1,88 tỷ', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '37170531'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Cao Lỗ, Phường 4, Quận 8, Hồ Chí Minh', 'Area': '24 m²', 'Price': '550 triệu', 'Bedroom': '1 phòng', 'Toilet': '1 phòng', 'Legal': 'Giấy tờ vi bằng, gác suốt', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38564509'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Bình Lợi, Phường 13, Bình Thạnh, Hồ Chí Minh', 'Area': '106 m²', 'Price': '7,5 tỷ', 'Direction': 'Nam', 'Bedroom': '3 phòng', 'Toilet': '2 phòng', 'Legal': 'Sổ đỏ/ sổ hồng', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '35521939'}
# {'Type': 'Nhà biệt thự, liền kề', 'Address': 'Dự án Tháp Mười Merita, Đường Liên Phường, Phường Phú Hữu, Quận 9, Hồ Chí Minh', 'Area': '85 m²', 'Price': '12,7 tỷ', 'Direction': 'Tây - Nam', 'Floor': '2 tầng', 'Bedroom': '3 phòng', 'Toilet': '3 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Đầy đủ.', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '37838052'}
# {'Type': 'Đất bán', 'Address': 'Phường Linh Tây, Thủ Đức, Hồ Chí Minh', 'Area': '172 m²', 'Price': 'Thỏa thuận', 'Legal': 'Sổ hồng chính chủ.', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38567446'}
# {'Type': 'Nhà mặt phố', 'Address': 'Đường Nguyễn Súy, Phường Tân Quý, Tân Phú, Hồ Chí Minh', 'Area': '76 m²', 'Price': '11,5 tỷ', 'Posting date': '13/11/2023', 'Expiry date': '13/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38542816'}
# {'Type': 'Nhà mặt phố', 'Address': 'Đường Nguyễn Văn Đậu, Phường 5, Phú Nhuận, Hồ Chí Minh', 'Area': '80 m²', 'Price': '17,3 tỷ', 'Direction': 'Tây - Nam', 'Floor': '6 tầng', 'Bedroom': '8 phòng', 'Toilet': '10 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Đầy đủ', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38565952'}
# {'Type': 'Nhà mặt phố', 'Address': 'Đường Lê Trọng Tấn, Phường Sơn Kỳ, Tân Phú, Hồ Chí Minh', 'Area': '160 m²', 'Price': '20 tỷ', 'Direction': 'Đông - Bắc', 'Floor': '3 tầng', 'Bedroom': '4 phòng', 'Toilet': '3 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Posting date': '10/11/2023', 'Expiry date': '10/12/2023', 'Ad type': 'Tin thường', 'Ad code': '36826264'}
# {'Type': 'Đất bán', 'Address': 'Phường An Phú Đông, Quận 12, Hồ Chí Minh', 'Area': '68 m²', 'Price': '4,38 tỷ', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38567175'}
# {'Type': 'Nhà biệt thự, liền kề', 'Address': 'Đường Ni Sư Huỳnh Liên, Phường 10, Tân Bình, Hồ Chí Minh', 'Area': '126 m²', 'Price': '19,9 tỷ', 'Floor': '5 tầng', 'Bedroom': '6 phòng', 'Toilet': '6 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Đầy đủ', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '37666293'}
# {'Type': 'Nhà riêng', 'Address': 'Phường Phú Thuận, Quận 7, Hồ Chí Minh', 'Area': '80 m²', 'Price': '12,3 tỷ', 'Floor': '3 tầng', 'Bedroom': '4 phòng', 'Toilet': '5 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Đầy đủ', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38565756'}
# {'Type': 'Nhà riêng', 'Address': '45, Đường Quốc Lộ 13, Phường Hiệp Bình Phước, Thủ Đức, Hồ Chí Minh', 'Area': '76,5 m²', 'Price': 'Thỏa thuận', 'Floor': '3 tầng', 'Bedroom': '3 phòng', 'Toilet': '3 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38236540'}
# {'Type': 'Căn hộ chung cư', 'Address': 'Dự án River Panorama, Đường Hoàng Quốc Việt, Phường Phú Thuận, Quận 7, Hồ Chí Minh', 'Area': '113,9 m²', 'Price': '3,8 tỷ', 'Bedroom': '3 phòng', 'Toilet': '2 phòng', 'Legal': 'Hợp đồng mua bán', 'Furniture': 'Đầy đủ', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38173171'}
# {'Type': 'Nhà mặt phố', 'Address': 'Đường Cư xá Nguyễn Văn Trỗi, Phường 8, Phú Nhuận, Hồ Chí Minh', 'Area': '98 m²', 'Price': '28 tỷ', 'Floor': '6 tầng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Đầy đủ', 'Posting date': '10/11/2023', 'Expiry date': '10/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38520341'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Cách Mạng Tháng Tám, Phường 11, Quận 3, Hồ Chí Minh', 'Area': '10,2 m²', 'Price': '3,3 tỷ', 'Floor': '2 tầng', 'Bedroom': '2 phòng', 'Toilet': '1 phòng', 'Legal': 'Đã có sổ', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38570232'}
# {'Type': 'Căn hộ chung cư', 'Address': 'Dự án The Era Town, Đường Số 15, Phường Phú Mỹ, Quận 7, Hồ Chí Minh', 'Area': '48 m²', 'Price': '1,6 tỷ', 'Direction': 'Nam', 'Bedroom': '1 phòng', 'Toilet': '1 phòng', 'Legal': 'Đã có sổ', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38567398'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Trương Thị Hoa, Phường Tân Thới Hiệp, Quận 12, Hồ Chí Minh', 'Area': '47,2 m²', 'Price': '3,39 tỷ', 'Direction': 'Tây - Bắc', 'Floor': '2 tầng', 'Bedroom': '2 phòng', 'Toilet': '2 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Đầy đủ', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38565812'}
# {'Type': 'Đất bán', 'Address': 'Đường Nguyễn Oanh, Phường 15, Gò Vấp, Hồ Chí Minh', 'Area': '60 m²', 'Price': '5,52 tỷ', 'Direction': 'Đông - Bắc', 'Legal': 'Đã có sổ.', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38565774'}
# {'Type': 'Căn hộ chung cư', 'Address': 'Dự án Khải Hoàn Prime, Đường Lê Văn Lương, Xã Nhơn Đức, Nhà Bè, Hồ Chí Minh', 'Area': '45,8 m²', 'Price': '2,2 tỷ', 'Direction': 'Nam', 'Bedroom': '1 phòng', 'Toilet': '1 phòng', 'Legal': 'Hợp đồng mua bán', 'Furniture': 'Đầy đủ', 'Posting date': '09/11/2023', 'Expiry date': '09/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38519647'}
# {'Type': 'Căn hộ chung cư', 'Address': 'Dự án C.T Plaza Minh Châu, Đường Lê Văn Sỹ, Phường 14, Quận 3, Hồ Chí Minh', 'Area': '28 m²', 'Price': '1,47 tỷ', 'Bedroom': '1 phòng', 'Toilet': '1 phòng', 'Legal': 'Hợp đồng mua bán', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '36693928'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Liên khu 4-5, Phường Bình Hưng Hòa B, Bình Tân, Hồ Chí Minh', 'Area': '56,36 m²', 'Price': '6,5 tỷ', 'Direction': 'Tây', 'Floor': '5 tầng', 'Bedroom': '4 phòng', 'Toilet': '5 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Cơ bản', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '37301467'}
# {'Type': 'Nhà riêng', 'Address': 'Hẻm 1244, Đường Lê Đức Thọ, Phường 12, Gò Vấp, Hồ Chí Minh', 'Area': '58,4 m²', 'Price': '6,7 tỷ', 'Direction': 'Nam', 'Floor': '5 tầng', 'Bedroom': '4 phòng', 'Toilet': '5 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng.', 'Furniture': 'Cơ bản.', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38565547'}
# {'Type': 'Đất nền dự án', 'Address': 'Dự án Long Trường Riverside, Đường Nguyễn Duy Trinh, Phường Long Trường, Quận 9, Hồ Chí Minh', 'Area': '58 m²', 'Price': '2,78 tỷ', 'Direction': 'Đông - Nam', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38236953'}
# {'Type': 'Căn hộ chung cư', 'Address': 'Dự án The Western Capital, Đường Lý Chiêu Hoàng, Phường 10, Quận 6, Hồ Chí Minh', 'Area': '50 m²', 'Price': '1,89 tỷ', 'Direction': 'Nam', 'Bedroom': '2 phòng', 'Toilet': '1 phòng', 'Legal': 'Hợp đồng mua bán', 'Furniture': 'Cơ bản.', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38565503'}
# {'Type': 'Nhà riêng', 'Address': '177/57, Đường Liên khu 4-5, Phường Bình Hưng Hòa B, Bình Tân, Hồ Chí Minh', 'Area': '104 m²', 'Price': '7,1 tỷ', 'Floor': '4 tầng', 'Legal': 'Đã có sổ hồng', 'Posting date': '11/11/2023', 'Expiry date': '11/12/2023', 'Ad type': 'Tin thường', 'Ad code': '37150846'}
# {'Type': 'Nhà riêng', 'Address': 'gần ngã tư tân quy, Xã Tân Thạnh Đông, Huyện Củ Chi, Tp Hồ Chí Minh', 'Area': '1.043,5 m²', 'Price': '16 tỷ', 'Direction': 'Tây', 'Legal': 'Đã có sổ', 'Posting date': '16/11/2023', 'Expiry date': '16/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38566531'}
# {'Type': 'Nhà mặt phố', 'Address': 'Đường Nguyễn Ảnh Thủ, Phường Hiệp Thành, Quận 12, Hồ Chí Minh', 'Area': '199,8 m²', 'Price': '25 tỷ', 'Direction': 'Bắc', 'Floor': '1 tầng', 'Bedroom': '4 phòng', 'Toilet': '3 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng.', 'Furniture': 'Đầy đủ.', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '37499390'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Trần Văn Khánh, Phường Tân Thuận Đông, Quận 7, Hồ Chí Minh', 'Area': '46 m²', 'Price': '2,3 tỷ', 'Direction': 'Nam', 'Floor': '2 tầng', 'Bedroom': '3 phòng', 'Toilet': '1 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Không nội thất', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '36750848'}
# {'Type': 'Căn hộ chung cư', 'Address': 'Zenity, 608, Đường Võ Văn Kiệt, Phường Cầu Kho, Quận 1, Hồ Chí Minh', 'Area': '77 m²', 'Price': '8,6 tỷ', 'Direction': 'Đông - Nam', 'Bedroom': '2 phòng', 'Toilet': '2 phòng', 'Legal': 'Đã ra sổ 50%', 'Furniture': 'Full nội thất đẹp', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38119121'}
# {'Type': 'Căn hộ chung cư', 'Address': 'Dự án Thủ Thiêm Green House, Đường Võ Chí Công, Phường  Thạnh Mỹ Lợi, Quận 2, Hồ Chí Minh', 'Area': '36 m²', 'Price': '900 triệu', 'Bedroom': '1 phòng', 'Toilet': '1 phòng', 'Furniture': 'Cơ bản', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38330034'}
# {'Type': 'Nhà mặt phố', 'Address': 'Đường Hương Lộ 3, Phường Sơn Kỳ, Tân Phú, Hồ Chí Minh', 'Area': '218 m²', 'Price': 'Thỏa thuận', 'Floor': '1 tầng', 'Bedroom': '3 phòng', 'Toilet': '2 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Đầy đủ', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38556366'}
# {'Type': 'Nhà mặt phố', 'Address': 'Đường Bà Điểm 5, Xã Xuân Thới Thượng, Hóc Môn, Hồ Chí Minh', 'Area': '95 m²', 'Price': '8 tỷ', 'Floor': '2 tầng', 'Bedroom': '3 phòng', 'Toilet': '4 phòng', 'Legal': 'Nhà mới xây pháp ly rô rang', 'Furniture': 'Cao cấp', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38562246'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Lê Văn Thọ, Phường 15, Gò Vấp, Hồ Chí Minh', 'Area': '64 m²', 'Price': '6,9 tỷ', 'Floor': '4 tầng', 'Bedroom': '4 phòng', 'Toilet': '4 phòng', 'Furniture': 'Đầy đủ', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38563128'}
# {'Type': 'Nhà mặt phố', 'Address': 'Đường  Nguyễn Thiện Thuật, Phường 12, Quận 3, Hồ Chí Minh', 'Area': '75 m²', 'Price': '19 tỷ', 'Floor': '5 tầng', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38262780'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Nguyễn Văn Trỗi, Phường 1, Phú Nhuận, Hồ Chí Minh', 'Area': '140 m²', 'Price': '30 tỷ', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38304245'}
# {'Type': 'Nhà mặt phố', 'Address': 'Đường Võ Văn Tần, Phường 5, Quận 3, Hồ Chí Minh', 'Area': '120 m²', 'Price': '48 tỷ', 'Floor': '5 tầng', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38468931'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Thoại Ngọc Hầu, Phường Phú Thạnh, Tân Phú, Hồ Chí Minh', 'Area': '48 m²', 'Price': 'Thỏa thuận', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38563606'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Lê Trọng Tấn, Phường Tây Thạnh, Tân Phú, Hồ Chí Minh', 'Area': '48 m²', 'Price': '4,7 tỷ', 'Floor': '2 tầng', 'Bedroom': '2 phòng', 'Toilet': '2 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38563544'}
# {'Type': 'Nhà riêng', 'Address': 'Đường  Thạch Lam, Phường Phú Thạnh, Tân Phú, Hồ Chí Minh', 'Area': '44 m²', 'Price': 'Thỏa thuận', 'Floor': '4 tầng', 'Bedroom': '3 phòng', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38563227'}
# {'Type': 'Nhà mặt phố', 'Address': 'Đường Nguyễn Cư Trinh, Phường Nguyễn Cư Trinh, Quận 1, Hồ Chí Minh', 'Area': '105,9 m²', 'Price': '26,5 tỷ', 'Floor': '3 tầng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Cơ bản', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38153794'}
# {'Type': 'Nhà riêng', 'Address': 'Đường 16, Phường Bình Hưng Hòa, Bình Tân, Hồ Chí Minh', 'Area': '87 m²', 'Price': '5,5 tỷ', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '37771874'}
# {'Type': 'Nhà riêng', 'Address': '4/, Đường Văn Chung, Phường 13, Tân Bình, Hồ Chí Minh', 'Area': '80 m²', 'Price': '9,9 tỷ', 'Direction': 'Đông - Bắc', 'Floor': '1 tầng', 'Bedroom': '2 phòng', 'Toilet': '2 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Cơ bản', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38273822'}
# {'Type': 'Nhà mặt phố', 'Address': 'Đường Quang Trung, Phường 11, Gò Vấp, Hồ Chí Minh', 'Area': '80 m²', 'Price': '12 tỷ', 'Floor': '2 tầng', 'Bedroom': '2 phòng', 'Toilet': '2 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Cơ bản', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38563008'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Lê Trọng Tấn, Phường Sơn Kỳ, Tân Phú, Hồ Chí Minh', 'Area': '92 m²', 'Price': '7,5 tỷ', 'Floor': '3 tầng', 'Bedroom': '3 phòng', 'Posting date': '12/11/2023', 'Expiry date': '12/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38535445'}
# {'Type': 'Nhà riêng', 'Address': 'Số 59/12 Bis, Đường Phạm Viết Chánh, Phường Nguyễn Cư Trinh, Quận 1, Hồ Chí Minh', 'Area': '376 m²', 'Price': '45 tỷ', 'Direction': 'Đông - Nam', 'Bedroom': '15 phòng', 'Toilet': '16 phòng', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38173737'}
# {'Type': 'Căn hộ chung cư', 'Address': 'Dự án Feliz En Vista, Đường Đồng Văn Cống, Phường  Thạnh Mỹ Lợi, Quận 2, Hồ Chí Minh', 'Area': '103 m²', 'Price': '8,8 tỷ', 'Bedroom': '2 phòng', 'Toilet': '2 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Đầy đủ', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '37858993'}
# {'Type': 'Nhà mặt phố', 'Address': 'Đường Đỗ Xuân Hợp, Phường Phước Long B, Quận 9, Hồ Chí Minh', 'Area': '148 m²', 'Price': '17,7 tỷ', 'Floor': '1 tầng', 'Bedroom': '1 phòng', 'Toilet': '1 phòng', 'Legal': 'Đã có sổ hồng.', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38563115'}
# {'Type': 'Nhà biệt thự, liền kề', 'Address': 'Phường 12, Quận 10, Hồ Chí Minh', 'Area': '157 m²', 'Price': '36 tỷ', 'Floor': '3 tầng', 'Bedroom': '5 phòng', 'Toilet': '5 phòng', 'Legal': 'Đã có sổ', 'Furniture': 'Full nội thất, có phòng gym trong nhà', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38562411'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Bùi Thị Xuân, Phường 5, Tân Bình, Hồ Chí Minh', 'Area': '50,4 m²', 'Price': '6,9 tỷ', 'Floor': '2 tầng', 'Bedroom': '2 phòng', 'Toilet': '2 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Đầy đủ', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38558895'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Huỳnh Tấn Phát, Phường Phú Thuận, Quận 7, Hồ Chí Minh', 'Area': '180,8 m²', 'Price': 'Thỏa thuận', 'Floor': '1 tầng', 'Bedroom': '4 phòng', 'Toilet': '2 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Đầy đủ', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38329123'}
# {'Type': 'Đất bán', 'Address': 'Xã An Thới Đông, Cần Giờ, Hồ Chí Minh', 'Area': '1.635 m²', 'Price': '4,8 tỷ', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '37840638'}
# {'Type': 'Nhà mặt phố', 'Address': 'Đường Lò Gốm, Phường 7, Quận 6, Hồ Chí Minh', 'Area': '150 m²', 'Price': '8,45 tỷ', 'Floor': '1 tầng', 'Bedroom': '3 phòng', 'Toilet': '3 phòng', 'Legal': 'Sổ hồng riêng', 'Furniture': 'Tặng nội thất', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38557393'}
# {'Type': 'Nhà riêng', 'Address': 'Hẻm 860 Đường Xô Viết Nghệ Tĩnh, Phường 25, Bình Thạnh, Hồ Chí Minh', 'Area': '184 m²', 'Price': '29 tỷ', 'Direction': 'Đông', 'Floor': '3 tầng', 'Bedroom': '12 phòng', 'Toilet': '13 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Đầy đủ', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38313182'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Dương Bá Trạc, Phường 2, Quận 8, Hồ Chí Minh', 'Area': '110 m²', 'Price': '19,9 tỷ', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38560724'}
# {'Type': 'Nhà biệt thự, liền kề', 'Address': 'Đường Tên Lửa, Phường Bình Trị Đông B, Bình Tân, Hồ Chí Minh', 'Area': '305,5 m²', 'Price': '27 tỷ', 'Posting date': '14/11/2023', 'Expiry date': '14/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38552120'}
# {'Type': 'Căn hộ chung cư', 'Address': 'Dự án Akari City Nam Long, Đường Võ Văn Kiệt, Phường An Lạc, Bình Tân, Hồ Chí Minh', 'Area': '75 m²', 'Price': '3,9 tỷ', 'Bedroom': '2 phòng', 'Toilet': '1 phòng', 'Legal': 'Hợp đồng mua bán', 'Furniture': 'Đầy đủ', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38331040'}
# {'Type': 'Nhà riêng', 'Address': 'Dự án Him Lam Kênh Tẻ, Phường Tân Hưng, Quận 7, Hồ Chí Minh', 'Area': '76,5 m²', 'Price': '16 tỷ', 'Floor': '3 tầng', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38561040'}
# {'Type': 'Căn hộ chung cư', 'Address': 'Dự án Diamond Island, Phường Bình Trưng Tây, Quận 2, Hồ Chí Minh', 'Area': '118 m²', 'Price': '12 tỷ', 'Bedroom': '2 phòng', 'Toilet': '2 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Đầy đủ', 'Posting date': '13/11/2023', 'Expiry date': '13/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38540727'}
# {'Type': 'Nhà riêng', 'Address': '87/, Đường Số 3, Phường Bình Hưng Hòa, Bình Tân, Hồ Chí Minh', 'Area': '56 m²', 'Price': '4,45 tỷ', 'Direction': 'Đông', 'Floor': '2 tầng', 'Bedroom': '1 phòng', 'Toilet': '1 phòng', 'Legal': 'Đã có sổ hồng', 'Furniture': 'Cơ bản', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38558614'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Thạnh Lộc 16, Phường Thạnh Lộc, Quận 12, Hồ Chí Minh', 'Area': '77 m²', 'Price': '5,85 tỷ', 'Direction': 'Đông - Nam', 'Bedroom': '4 phòng', 'Toilet': '4 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38468107'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Lê Văn Khương, Phường Thới An, Quận 12, Hồ Chí Minh', 'Area': '56 m²', 'Price': '6,3 tỷ', 'Direction': 'Đông - Bắc', 'Floor': '4 tầng', 'Bedroom': '4 phòng', 'Toilet': '4 phòng', 'Furniture': 'Full thiết bị, tivi, sofa, bàn ăn.', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38560157'}
# {'Type': 'Căn hộ chung cư', 'Address': 'Dự án Feliz En Vista, Đường Đồng Văn Cống, Phường  Thạnh Mỹ Lợi, Quận 2, Hồ Chí Minh', 'Area': '116 m²', 'Price': '8,6 tỷ', 'Bedroom': '2 phòng', 'Toilet': '2 phòng', 'Legal': 'Đang chờ sổ', 'Furniture': 'Đầy đủ', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '37477426'}
# {'Type': 'Đất nền dự án', 'Address': 'Dự án Thạnh Mỹ Lợi, Phường  Thạnh Mỹ Lợi, Quận 2, Hồ Chí Minh', 'Area': '300 m²', 'Price': '75 triệu/m²', 'Direction': 'Đông - Nam', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '33937256'}
# {'Type': 'Đất nền dự án', 'Address': 'Dự án Huy Hoàng, Đường Tỉnh lộ 25B, Phường  Thạnh Mỹ Lợi, Quận 2, Hồ Chí Minh', 'Area': '152 m²', 'Price': '255 triệu/m²', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '37514195'}
# {'Type': 'Đất nền dự án', 'Address': 'Dự án Huy Hoàng, Đường Tỉnh lộ 25B, Phường  Thạnh Mỹ Lợi, Quận 2, Hồ Chí Minh', 'Area': '152 m²', 'Price': '255 triệu/m²', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '37514195'}
# {'Type': 'Căn hộ chung cư', 'Address': 'Wilton Tower, 71/3, Đường Nguyễn Văn Thương, Phường 25, Bình Thạnh, Hồ Chí Minh', 'Area': '68 m²', 'Price': '3,85 tỷ', 'Direction': 'Đông - Nam', 'Bedroom': '2 phòng', 'Toilet': '2 phòng', 'Posting date': '09/11/2023', 'Expiry date': '09/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38287968'}
# {'Type': 'Đất nền dự án', 'Address': 'Dự án Saigon Mystery Villas, Phường Bình Trưng Tây, Quận 2, Hồ Chí Minh', 'Area': '150 m²', 'Price': '175 triệu/m²', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '37514316'}
# {'Type': 'Đất nền dự án', 'Address': 'Dự án Thủ Thiêm Villa, Phường  Thạnh Mỹ Lợi, Quận 2, Hồ Chí Minh', 'Area': '271,8 m²', 'Price': '140 triệu/m²', 'Direction': 'Nam', 'Legal': 'Sổ đỏ/ Sổ hồng.', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '37969629'}
# {'Type': 'Đất nền dự án', 'Address': 'Dự án Thạnh Mỹ Lợi - Phú Nhuận 1,2, Đường Nguyễn Văn Kỉnh, Phường  Thạnh Mỹ Lợi, Quận 2, Hồ Chí Minh', 'Area': '129,5 m²', 'Price': '115 triệu/m²', 'Legal': 'Sổ đỏ', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '37514249'}
# {'Type': 'Đất nền dự án', 'Address': 'Dự án KDC Thế kỉ 21, Phường  Thạnh Mỹ Lợi, Quận 2, Hồ Chí Minh', 'Area': '160 m²', 'Price': '125 triệu/m²', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '37514284'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Đất Thánh, Phường 6, Tân Bình, Hồ Chí Minh', 'Area': '92,8 m²', 'Price': '14,69 tỷ', 'Direction': 'Tây', 'Floor': '4 tầng', 'Bedroom': '6 phòng', 'Toilet': '5 phòng', 'Legal': 'Sổ hồng riêng.', 'Furniture': 'Nội thất đầy đủ', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '37761600'}
# {'Type': 'Đất nền dự án', 'Address': 'Dự án Thủ Thiêm Villa, Phường  Thạnh Mỹ Lợi, Quận 2, Hồ Chí Minh', 'Area': '278,1 m²', 'Price': '135 triệu/m²', 'Direction': 'Tây', 'Legal': 'Hợp đồng mua bán', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38206662'}
# {'Type': 'Nhà biệt thự, liền kề', 'Address': 'Dự án Phú Mỹ 2, Đường Phạm Hữu Lầu, Phường Phú Mỹ, Quận 7, Hồ Chí Minh', 'Area': '90 m²', 'Price': '14 tỷ', 'Floor': '4 tầng', 'Bedroom': '4 phòng', 'Toilet': '4 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '35782304'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Lê Văn Sỹ, Phường 13, Quận 3, Hồ Chí Minh', 'Area': '91,7 m²', 'Price': '18 tỷ', 'Direction': 'Đông - Bắc', 'Floor': '4 tầng', 'Bedroom': '3 phòng', 'Toilet': '3 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Cơ bản', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '37975658'}
# {'Type': 'Nhà riêng', 'Address': 'Dự án KDC Phú Mỹ, Đường Hoàng Quốc Việt, Phường Phú Mỹ, Quận 7, Hồ Chí Minh', 'Area': '126 m²', 'Price': '19 tỷ', 'Bedroom': '4 phòng', 'Toilet': '5 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '37930721'}
# {'Type': 'Đất bán', 'Address': 'Đường 26, Phường Phước Long A, Quận 9, Hồ Chí Minh', 'Area': '87,3 m²', 'Price': '7 tỷ', 'Posting date': '15/11/2023', 'Expiry date': '15/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38559354'}
# ...
# {'Type': 'Căn hộ chung cư', 'Address': 'Dự án Ehome S, Phường Phú Hữu, Quận 9, Hồ Chí Minh', 'Area': '60 m²', 'Price': '1,43 tỷ', 'Bedroom': '2 phòng', 'Toilet': '2 phòng', 'Posting date': '08/11/2023', 'Expiry date': '08/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38505780'}
# {'Type': 'Căn hộ chung cư', 'Address': 'Dự án Thạnh Mỹ Lợi, Đường Đồng Văn Cống, Phường  Thạnh Mỹ Lợi, Quận 2, Hồ Chí Minh', 'Area': '60 m²', 'Price': '1,82 tỷ', 'Direction': 'Đông - Nam', 'Bedroom': '2 phòng', 'Toilet': '2 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Full nội thất: 02 máy lạnh, tivi, tủ lạnh, máy giặt, giường tủ...', 'Posting date': '08/11/2023', 'Expiry date': '08/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38072980'}
# {'Type': 'Căn hộ chung cư', 'Address': 'Dự án Zeit River Thủ Thiêm , Phường An Khánh, Quận 2, Hồ Chí Minh', 'Area': '230 m²', 'Price': '42 tỷ', 'Bedroom': '4 phòng', 'Toilet': '3 phòng', 'Legal': 'Hợp đồng mua bán', 'Furniture': 'Cơ bản', 'Posting date': '08/11/2023', 'Expiry date': '08/12/2023', 'Ad type': 'Tin thường', 'Ad code': '37849892'}
# {'Type': 'Nhà riêng', 'Address': 'Phường Hiệp Thành, Quận 12, Hồ Chí Minh', 'Area': '40 m²', 'Price': '1,98 tỷ', 'Floor': '2 tầng', 'Bedroom': '2 phòng', 'Toilet': '2 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Đầy đủ', 'Posting date': '08/11/2023', 'Expiry date': '08/12/2023', 'Ad type': 'Tin thường', 'Ad code': '37278939'}
# {'Type': 'Nhà mặt phố', 'Address': 'Đường Lê Hồng Phong, Phường 12, Quận 10, Hồ Chí Minh', 'Area': '96 m²', 'Price': '40 tỷ', 'Posting date': '08/11/2023', 'Expiry date': '08/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38506381'}
# {'Type': 'Căn hộ chung cư', 'Address': 'Dự án Feliz En Vista, Đường Đồng Văn Cống, Phường  Thạnh Mỹ Lợi, Quận 2, Hồ Chí Minh', 'Area': '103 m²', 'Price': '8,2 tỷ', 'Bedroom': '2 phòng', 'Toilet': '2 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Đầy đủ', 'Posting date': '08/11/2023', 'Expiry date': '08/12/2023', 'Ad type': 'Tin thường', 'Ad code': '37609182'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Làng Tăng Phú, Phường Tăng Nhơn Phú A, Quận 9, Hồ Chí Minh', 'Area': '59,5 m²', 'Price': '6,5 tỷ', 'Direction': 'Đông - Bắc', 'Floor': '3 tầng', 'Bedroom': '3 phòng', 'Toilet': '4 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Đầy đủ', 'Posting date': '08/11/2023', 'Expiry date': '08/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38070909'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Lê Hồng Phong, Phường 2, Quận 10, Hồ Chí Minh', 'Area': '73 m²', 'Price': '9 tỷ', 'Posting date': '08/11/2023', 'Expiry date': '08/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38506334'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Số 48, Phường Hiệp Bình Chánh, Thủ Đức, Hồ Chí Minh', 'Area': '68 m²', 'Price': 'Thỏa thuận', 'Floor': '2 tầng', 'Bedroom': '3 phòng', 'Toilet': '2 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Cơ bản', 'Posting date': '08/11/2023', 'Expiry date': '08/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38173059'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Quốc Lộ 13, Phường Hiệp Bình Phước, Thủ Đức, Hồ Chí Minh', 'Area': '80 m²', 'Price': 'Thỏa thuận', 'Floor': '4 tầng', 'Bedroom': '5 phòng', 'Toilet': '6 phòng', 'Posting date': '08/11/2023', 'Expiry date': '08/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38254854'}
# {'Type': 'Nhà riêng', 'Address': 'Đường 146 Lã Xuân Oai, Phường Tăng Nhơn Phú A, Quận 9, Hồ Chí Minh', 'Area': '50 m²', 'Price': '5 tỷ', 'Floor': '3 tầng', 'Bedroom': '4 phòng', 'Toilet': '3 phòng', 'Posting date': '08/11/2023', 'Expiry date': '08/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38073966'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Lã Xuân Oai, Phường Tăng Nhơn Phú A, Quận 9, Hồ Chí Minh', 'Area': '56 m²', 'Price': '3,4 tỷ', 'Floor': '2 tầng', 'Bedroom': '2 phòng', 'Toilet': '2 phòng', 'Posting date': '08/11/2023', 'Expiry date': '08/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38091206'}
# {'Type': 'Nhà riêng', 'Address': 'Đường 182, Phường Tăng Nhơn Phú A, Quận 9, Hồ Chí Minh', 'Area': '37,5 m²', 'Price': '3,2 tỷ', 'Floor': '2 tầng', 'Bedroom': '2 phòng', 'Toilet': '2 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Posting date': '08/11/2023', 'Expiry date': '08/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38123329'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Làng Tăng Phú, Phường Tăng Nhơn Phú A, Quận 9, Hồ Chí Minh', 'Area': '80 m²', 'Price': 'Thỏa thuận', 'Floor': '2 tầng', 'Bedroom': '2 phòng', 'Toilet': '1 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Đầy đủ', 'Posting date': '08/11/2023', 'Expiry date': '08/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38169765'}
# {'Type': 'Nhà riêng', 'Address': 'Đường 160, Phường Tăng Nhơn Phú A, Quận 9, Hồ Chí Minh', 'Area': '45,8 m²', 'Price': '2,8 tỷ', 'Floor': '1 tầng', 'Bedroom': '1 phòng', 'Toilet': '1 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Posting date': '08/11/2023', 'Expiry date': '08/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38123334'}
# {'Type': 'Căn hộ chung cư', 'Address': 'Dự án The Grand Manhattan, Đường Cô Bắc, Phường Cô Giang, Quận 1, Hồ Chí Minh', 'Area': '96 m²', 'Price': '15 tỷ', 'Bedroom': '3 phòng', 'Posting date': '08/11/2023', 'Expiry date': '08/12/2023', 'Ad type': 'Tin thường', 'Ad code': '37584916'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Huỳnh Văn Trí, Xã Bình Chánh, Bình Chánh, Hồ Chí Minh', 'Area': '70 m²', 'Price': 'Thỏa thuận', 'Bedroom': '3 phòng', 'Toilet': '2 phòng', 'Furniture': 'Nội thất cơ bản.', 'Posting date': '08/11/2023', 'Expiry date': '08/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38504463'}
# {'Type': 'Nhà mặt phố', 'Address': 'Đường Võ Văn Tần, Phường 5, Quận 3, Hồ Chí Minh', 'Area': '92 m²', 'Price': '65 tỷ', 'Floor': '4 tầng', 'Posting date': '08/11/2023', 'Expiry date': '08/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38506361'}
# {'Type': 'Căn hộ chung cư', 'Address': 'Dự án The River Thủ Thiêm, Đường Nguyễn Cơ Thạch, Phường An Khánh, Quận 2, Hồ Chí Minh', 'Area': '186 m²', 'Price': '59 tỷ', 'Bedroom': '4 phòng', 'Legal': 'Đang chờ sổ', 'Furniture': 'Đầy đủ', 'Posting date': '08/11/2023', 'Expiry date': '08/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38506491'}
# {'Type': 'Nhà mặt phố', 'Address': 'Đường Hoàng Sa, Phường Tân Định, Quận 1, Hồ Chí Minh', 'Area': '40 m²', 'Price': '14,5 tỷ', 'Posting date': '08/11/2023', 'Expiry date': '08/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38506343'}
# {'Type': 'Nhà mặt phố', 'Address': 'Đường Phan Tây Hồ, Phường 7, Phú Nhuận, Hồ Chí Minh', 'Area': '134 m²', 'Price': '23 tỷ', 'Posting date': '08/11/2023', 'Expiry date': '08/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38506374'}
# {'Type': 'Căn hộ chung cư', 'Address': 'Dự án Miếu Nổi, Đường Vũ Huy Tấn, Phường 3, Bình Thạnh, Hồ Chí Minh', 'Area': '51,7 m²', 'Price': '2,55 tỷ', 'Bedroom': '2 phòng', 'Toilet': '1 phòng', 'Furniture': 'Đầy đủ', 'Posting date': '08/11/2023', 'Expiry date': '08/12/2023', 'Ad type': 'Tin thường', 'Ad code': '37420994'}
# {'Type': 'Bất động sản khác', 'Address': '138, Đường Hà Huy Giáp, Phường Thạnh Lộc, Quận 12, Hồ Chí Minh', 'Area': '6.265 m²', 'Price': '260 tỷ', 'Floor': '7 tầng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Đầy đủ', 'Posting date': '08/11/2023', 'Expiry date': '08/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38278580'}
# {'Type': 'Nhà riêng', 'Address': 'Đường  Trần Xuân Soạn, Phường Tân Hưng, Quận 7, Hồ Chí Minh', 'Area': '88 m²', 'Price': '6,2 tỷ', 'Floor': '3 tầng', 'Bedroom': '4 phòng', 'Toilet': '4 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Đầy đủ', 'Posting date': '09/12/2023', 'Expiry date': '08/01/2024', 'Ad type': 'Tin thường', 'Ad code': '37143199'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Quốc lộ 1A, Phường Tân Thới Hiệp, Quận 12, Hồ Chí Minh', 'Area': '60 m²', 'Price': '3,3 tỷ', 'Direction': 'Tây', 'Floor': '1 tầng', 'Bedroom': '2 phòng', 'Toilet': '1 phòng', 'Legal': 'Sổ hồng', 'Posting date': '08/12/2023', 'Expiry date': '07/01/2024', 'Ad type': 'Tin thường', 'Ad code': '38001164'}
# {'Type': 'Nhà riêng', 'Address': 'Phường Hiệp Bình Phước, Thành phố Thủ Đức, Hồ Chí Minh', 'Area': '104 m²', 'Price': '9,5 tỷ', 'Floor': '3 tầng', 'Bedroom': '4 phòng', 'Toilet': '4 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Cơ bản', 'Posting date': '08/11/2023', 'Expiry date': '08/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38044578'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Tân Quý, Phường Tân Quý, Tân Phú, Hồ Chí Minh', 'Area': '69 m²', 'Price': '9,5 tỷ', 'Floor': '3 tầng', 'Bedroom': '5 phòng', 'Toilet': '4 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Đầy đủ', 'Posting date': '08/11/2023', 'Expiry date': '08/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38505801'}
# {'Type': 'Căn hộ chung cư', 'Address': 'Dự án De La Sol, Đường Tôn Thất Thuyết, Phường 1, Quận 4, Hồ Chí Minh', 'Area': '81,83 m²', 'Price': '6,79 tỷ', 'Bedroom': '2 phòng', 'Toilet': '2 phòng', 'Legal': 'Hợp đồng mua bán', 'Furniture': 'Đầy đủ', 'Posting date': '08/11/2023', 'Expiry date': '08/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38278170'}
# {'Type': 'Căn hộ chung cư', 'Address': 'Dự án Green River quận 8, Đường Phạm Thế Hiển, Phường 6, Quận 8, Hồ Chí Minh', 'Area': '85 m²', 'Price': '3,3 tỷ', 'Bedroom': '3 phòng', 'Toilet': '2 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Đầy đủ', 'Posting date': '08/11/2023', 'Expiry date': '08/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38505606'}
# {'Type': 'Căn hộ chung cư', 'Address': 'Dự án Feliz En Vista, Đường Trương Văn Bang, Phường  Thạnh Mỹ Lợi, Quận 2, Hồ Chí Minh', 'Area': '107 m²', 'Price': '10,8 tỷ', 'Bedroom': '3 phòng', 'Toilet': '2 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Đầy đủ', 'Posting date': '08/11/2023', 'Expiry date': '08/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38505068'}
# {'Type': 'Căn hộ chung cư', 'Address': 'Dự án Topaz Elite, Đường Cao Lỗ, Phường 4, Quận 8, Hồ Chí Minh', 'Area': '85 m²', 'Price': '2,69 tỷ', 'Bedroom': '3 phòng', 'Toilet': '2 phòng', 'Legal': 'Hợp đồng mua bán', 'Furniture': 'Không nội thất', 'Posting date': '08/11/2023', 'Expiry date': '08/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38094915'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Nguyễn Duy Trinh, Phường Bình Trưng Đông, Quận 2, Hồ Chí Minh', 'Area': '52 m²', 'Price': '4,4 tỷ', 'Floor': '4 tầng', 'Bedroom': '4 phòng', 'Toilet': '3 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Đầy đủ', 'Posting date': '08/11/2023', 'Expiry date': '08/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38504594'}
# {'Type': 'Căn hộ chung cư', 'Address': 'Dự án Opal Riverside, Đường 10, Phường Hiệp Bình Chánh, Thủ Đức, Hồ Chí Minh.', 'Area': '71 m²', 'Price': '3,2 tỷ', 'Direction': 'Đông - Bắc', 'Bedroom': '2 phòng', 'Toilet': '2 phòng', 'Legal': 'Hợp đồng mua bán.', 'Furniture': 'Cơ bản.', 'Posting date': '08/11/2023', 'Expiry date': '08/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38504635'}
# {'Type': 'Đất bán', 'Address': 'Đường Thạnh Xuân 24, Phường Thạnh Xuân, Quận 12, Hồ Chí Minh', 'Area': '75,3 m²', 'Price': '3,8 tỷ', 'Direction': 'Đông', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Posting date': '08/11/2023', 'Expiry date': '08/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38500918'}
# {'Type': 'Đất nền dự án', 'Address': 'Dự án Sadeco Nghỉ ngơi giải trí Quận 7, Đường Nguyễn Văn Linh, Phường Tân Phong, Quận 7, Hồ Chí Minh', 'Area': '237,5 m²', 'Price': '31,5 tỷ', 'Legal': 'Sổ hồng', 'Posting date': '08/11/2023', 'Expiry date': '08/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38504524'}
# {'Type': 'Căn hộ chung cư', 'Address': 'Dự án Vinhomes Golden River Ba Son, Phố Tôn Đức Thắng, Phường Bến Nghé, Quận 1, Hồ Chí Minh.', 'Area': '80 m²', 'Price': '8 tỷ', 'Bedroom': '2 phòng', 'Toilet': '2 phòng', 'Legal': 'Đang chờ sổ.', 'Furniture': 'Đầy đủ', 'Posting date': '09/12/2023', 'Expiry date': '24/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38503556'}
# {'Type': 'Nhà biệt thự, liền kề', 'Address': 'Dự án KĐT Vạn Phúc City, Đường Đinh Thị Thi, Phường Hiệp Bình Phước, Thủ Đức, Hồ Chí Minh', 'Area': '140 m²', 'Price': '24,5 tỷ', 'Floor': '5 tầng', 'Posting date': '08/11/2023', 'Expiry date': '08/12/2023', 'Ad type': 'Tin thường', 'Ad code': '37972826'}
# {'Type': 'Nhà mặt phố', 'Address': 'Phường An Phú, Quận 2, Hồ Chí Minh.', 'Area': '256 m²', 'Price': 'Thỏa thuận', 'Direction': 'Đông - Nam', 'Floor': '6 tầng', 'Toilet': '6 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Cơ bản', 'Posting date': '08/11/2023', 'Expiry date': '08/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38503462'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Bình Lợi, Phường 13, Bình Thạnh, Hồ Chí Minh', 'Area': '160 m²', 'Price': '24 tỷ', 'Floor': '5 tầng', 'Bedroom': '18 phòng', 'Toilet': '19 phòng', 'Posting date': '11/12/2023', 'Expiry date': '21/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38504528'}
# {'Type': 'Nhà biệt thự, liền kề', 'Address': 'Đường Hồng Hạc, Phường 10, Tân Bình, Hồ Chí Minh', 'Area': '126 m²', 'Price': '19,9 tỷ', 'Bedroom': '6 phòng', 'Toilet': '6 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Đầy đủ', 'Posting date': '09/12/2023', 'Expiry date': '08/01/2024', 'Ad type': 'Tin thường', 'Ad code': '37833255'}
# {'Type': 'Đất nền dự án', 'Address': 'Samsung Village, Hẻm 1/, Đường Bưng Ông Thoàn, Phường Phú Hữu, Quận 9, Hồ Chí Minh', 'Area': '78,2 m²', 'Price': '4 tỷ', 'Direction': 'Tây - Bắc', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Posting date': '08/11/2023', 'Expiry date': '08/12/2023', 'Ad type': 'Tin thường', 'Ad code': '37918710'}
# {'Type': 'Nhà biệt thự, liền kề', 'Address': 'Đường Lê Văn Quới, Phường Bình Trị Đông A, Bình Tân, Hồ Chí Minh', 'Area': '140 m²', 'Price': '11,5 tỷ', 'Bedroom': '4 phòng', 'Toilet': '4 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Cơ bản', 'Posting date': '09/12/2023', 'Expiry date': '08/01/2024', 'Ad type': 'Tin thường', 'Ad code': '38044209'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Chu Văn An, Phường 12, Bình Thạnh, Hồ Chí Minh', 'Area': '36 m²', 'Price': 'Thỏa thuận', 'Floor': '3 tầng', 'Bedroom': '3 phòng', 'Toilet': '3 phòng', 'Posting date': '08/11/2023', 'Expiry date': '08/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38509245'}
# {'Type': 'Nhà mặt phố', 'Address': 'Đường Nguyễn Sáng, Phường Tây Thạnh, Tân Phú, Hồ Chí Minh', 'Area': '144 m²', 'Price': '16,5 tỷ', 'Floor': '7 tầng', 'Bedroom': '40 phòng', 'Toilet': '42 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Đầy đủ', 'Posting date': '08/11/2023', 'Expiry date': '08/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38500057'}
# {'Type': 'Nhà mặt phố', 'Address': 'Dự án KĐT Vạn Phúc City, Đường Nguyễn Thị Nhung, Phường Hiệp Bình Phước, Thủ Đức, Hồ Chí Minh', 'Area': '140 m²', 'Price': '34 tỷ', 'Floor': '6 tầng', 'Bedroom': '5 phòng', 'Toilet': '6 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng.', 'Posting date': '09/12/2023', 'Expiry date': '08/01/2024', 'Ad type': 'Tin thường', 'Ad code': '38016583'}
# {'Type': 'Nhà mặt phố', 'Address': 'Phường 8, Gò Vấp, Hồ Chí Minh', 'Area': '66 m²', 'Price': '6,7 tỷ', 'Floor': '3 tầng', 'Bedroom': '4 phòng', 'Toilet': '6 phòng', 'Legal': 'Đã có sổ đất ở đô thị sở hữu lâu dài', 'Furniture': 'Đầy đủ cơ bản', 'Posting date': '08/11/2023', 'Expiry date': '08/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38500616'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Nguyễn Văn Lượng, Phường 17, Gò Vấp, Hồ Chí Minh', 'Area': '63 m²', 'Price': '5,7 tỷ', 'Direction': 'Nam', 'Floor': '1 tầng', 'Bedroom': '1 phòng', 'Toilet': '1 phòng', 'Legal': 'Sổ đỏ/ Sổ hồng', 'Furniture': 'Không nội thất', 'Posting date': '08/11/2023', 'Expiry date': '08/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38499922'}
# {'Type': 'Nhà riêng', 'Address': 'Đường Hòa Hưng, Phường 13, Quận 10, Hồ Chí Minh', 'Area': '114,4 m²', 'Price': 'Thỏa thuận', 'Direction': 'Đông - Nam', 'Floor': '2 tầng', 'Bedroom': '4 phòng', 'Toilet': '2 phòng', 'Legal': 'Sổ hồng 2007', 'Furniture': 'Ko', 'Posting date': '08/11/2023', 'Expiry date': '08/12/2023', 'Ad type': 'Tin thường', 'Ad code': '38500275'}

# %% [markdown]
# Up to now, we are successfully collect the data, with above 50.000 samples and tooks me about nearly about 12 hours for all of them. As you can see, I divided the collecting process by range to ensure and keep tract the result, Also I don't want put too much pressure on my computer too.

# %% [markdown]
# ### **4. Store the collected data to csv file:**
#
# Finally, just store the data into a `csv` file and finish the process.

# %%
df.to_csv('../Data/real_estate_for_sale.csv', index = False)

# %%
real_estate_df = pd.read_csv('../Data/real_estate_for_sale.csv')

# %%
real_estate_df.shape()
